# %%
import numpy as np
import os
import time
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Dropout, Flatten, BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import random
from PointNet import PointNet

from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, recall_score, precision_score, f1_score, classification_report

DATA_PATH = os.path.join('Keypoint Dataset', 'V3')
actions = np.array([folder for folder in os.listdir(DATA_PATH)])

# %%
label_map = {label:num for num, label in enumerate(actions)}

dataset, labels = [], []
for action in actions:
    for data in range(len(os.listdir(os.path.join(DATA_PATH, action)))):
        res = np.load(os.path.join(DATA_PATH, action, "{}.npy".format(data)), allow_pickle=True)
        dataset.append(res)
        labels.append(label_map[action])

# %%
X = np.array(dataset)

y = to_categorical(labels).astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6)

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
def build_model():
    cnnModel = Sequential([
        Conv1D(32, 3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
        MaxPool1D(),
        Conv1D(64, 3, activation='relu'),
        MaxPool1D(),
        Conv1D(128, 3, activation='relu'),
        MaxPool1D(),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(actions.shape[0], activation='softmax')
    ])

    cnnModel.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return cnnModel

# %%
cnnModel = build_model()
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

startTime = time.time()
history = cnnModel.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
endTime = time.time()
print("Training Duration: ", endTime - startTime)

cnnModel.save('CNN V3.h5')
predictions = cnnModel.predict(X_test)

predictions = [np.argmax(pred) for pred in predictions]
y_test2 = [np.argmax(y_val) for y_val in y_test]
acc = accuracy_score(y_test2, predictions)
# Out:
# C:\Users\leozh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.1001 - loss: 2.9505 - val_accuracy: 0.3055 - val_loss: 2.8706
# Epoch 2/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2411 - loss: 2.4409 - val_accuracy: 0.4352 - val_loss: 2.7336
# Epoch 3/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3587 - loss: 2.0861 - val_accuracy: 0.4813 - val_loss: 2.5193
# Epoch 4/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4622 - loss: 1.7917 - val_accuracy: 0.5389 - val_loss: 2.1361
# Epoch 5/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5280 - loss: 1.5735 - val_accuracy: 0.6744 - val_loss: 1.7074
# Epoch 6/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6021 - loss: 1.3910 - val_accuracy: 0.6715 - val_loss: 1.3588
# Epoch 7/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6059 - loss: 1.3254 - val_accuracy: 0.7118 - val_loss: 1.0755
# Epoch 8/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6643 - loss: 1.1700 - val_accuracy: 0.7291 - val_loss: 0.9515
# Epoch 9/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6724 - loss: 1.0518 - val_accuracy: 0.7262 - val_loss: 0.8787
# Epoch 10/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7132 - loss: 1.0071 - val_accuracy: 0.7666 - val_loss: 0.7852
# Epoch 11/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7235 - loss: 0.9432 - val_accuracy: 0.7637 - val_loss: 0.7923
# Epoch 12/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7344 - loss: 0.8600 - val_accuracy: 0.7896 - val_loss: 0.7100
# Epoch 13/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7548 - loss: 0.8234 - val_accuracy: 0.7983 - val_loss: 0.7331
# Epoch 14/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7867 - loss: 0.7364 - val_accuracy: 0.8271 - val_loss: 0.6275
# Epoch 15/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7859 - loss: 0.7118 - val_accuracy: 0.8184 - val_loss: 0.6570
# Epoch 16/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7866 - loss: 0.6914 - val_accuracy: 0.8242 - val_loss: 0.6155
# Epoch 17/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8015 - loss: 0.6688 - val_accuracy: 0.8271 - val_loss: 0.5839
# Epoch 18/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8169 - loss: 0.6102 - val_accuracy: 0.8213 - val_loss: 0.6396
# Epoch 19/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8306 - loss: 0.5596 - val_accuracy: 0.8473 - val_loss: 0.5733
# Epoch 20/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8301 - loss: 0.5424 - val_accuracy: 0.8415 - val_loss: 0.5521
# Epoch 21/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8434 - loss: 0.5188 - val_accuracy: 0.8329 - val_loss: 0.5492
# Epoch 22/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8403 - loss: 0.5172 - val_accuracy: 0.8300 - val_loss: 0.5495
# Epoch 23/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8590 - loss: 0.4657 - val_accuracy: 0.8156 - val_loss: 0.5558
# Epoch 24/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8713 - loss: 0.4505 - val_accuracy: 0.8271 - val_loss: 0.5375
# Epoch 25/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8731 - loss: 0.4346 - val_accuracy: 0.8329 - val_loss: 0.5940
# Epoch 26/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8810 - loss: 0.3827 - val_accuracy: 0.8415 - val_loss: 0.5546
# Epoch 27/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8761 - loss: 0.4199 - val_accuracy: 0.8184 - val_loss: 0.6042
# Epoch 28/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8755 - loss: 0.4062 - val_accuracy: 0.8213 - val_loss: 0.5735
# Epoch 29/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8850 - loss: 0.3911 - val_accuracy: 0.8357 - val_loss: 0.5669
# Epoch 30/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8875 - loss: 0.3687 - val_accuracy: 0.8242 - val_loss: 0.6126
# Epoch 31/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8918 - loss: 0.3324 - val_accuracy: 0.8329 - val_loss: 0.5656
# Epoch 32/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9127 - loss: 0.3138 - val_accuracy: 0.8559 - val_loss: 0.5324
# Epoch 33/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8866 - loss: 0.3788 - val_accuracy: 0.8790 - val_loss: 0.5058
# Epoch 34/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9018 - loss: 0.3210 - val_accuracy: 0.8329 - val_loss: 0.6185
# Epoch 35/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8840 - loss: 0.3392 - val_accuracy: 0.8444 - val_loss: 0.5012
# Epoch 36/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9099 - loss: 0.2919 - val_accuracy: 0.8473 - val_loss: 0.5235
# Epoch 37/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9062 - loss: 0.3079 - val_accuracy: 0.8501 - val_loss: 0.6166
# Epoch 38/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9144 - loss: 0.2908 - val_accuracy: 0.8415 - val_loss: 0.6343
# Epoch 39/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9168 - loss: 0.2666 - val_accuracy: 0.8559 - val_loss: 0.5522
# Epoch 40/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9237 - loss: 0.2490 - val_accuracy: 0.8300 - val_loss: 0.6459
# Epoch 41/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9221 - loss: 0.2676 - val_accuracy: 0.8501 - val_loss: 0.5893
# Epoch 42/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9295 - loss: 0.2400 - val_accuracy: 0.8415 - val_loss: 0.6061
# Epoch 43/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9217 - loss: 0.2580 - val_accuracy: 0.8588 - val_loss: 0.5782
# Epoch 44/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9276 - loss: 0.2295 - val_accuracy: 0.8386 - val_loss: 0.6160
# Epoch 45/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9248 - loss: 0.2525 - val_accuracy: 0.8530 - val_loss: 0.5535
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training Duration:  54.16837763786316
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step

# %%
predictions = cnnModel.predict(X_test)

predictions = [np.argmax(pred) for pred in predictions]
y_test2 = [np.argmax(y_val) for y_val in y_test]
display = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test2, predictions), display_labels = actions)
print(f"Accuracy: {accuracy_score(y_test2, predictions)}")
print(f"Precision Score: {precision_score(y_test2, predictions, average='weighted')}")
print(f"Recall Score: {recall_score(y_test2, predictions, average='weighted')}")
print(f"F1 Score: {f1_score(y_test2, predictions, average='weighted')}")

print(f"Classification Report: {classification_report(y_test2, predictions, target_names=actions)}")

fig, ax = plt.subplots(figsize=(8,8))
print(f"Confusion Matrix:\n")
display.plot(ax=ax, xticks_rotation='vertical')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('CNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('CNN Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Accuracy: 0.884393063583815
# Precision Score: 0.8930801840676545
# Recall Score: 0.884393063583815
# F1 Score: 0.8854306249222231
# Classification Report:               precision    recall  f1-score   support
#
#         Anda       0.91      0.88      0.89        24
#          Apa       0.88      0.95      0.91        22
#     Berhenti       1.00      1.00      1.00        11
#        Bodoh       1.00      0.81      0.90        16
#       Cantik       1.00      0.86      0.92        14
#         Halo       1.00      1.00      1.00         8
#    Hati-hati       0.94      0.88      0.91        17
#        Lelah       1.00      0.93      0.97        15
#         Maaf       1.00      1.00      1.00        24
#        Makan       0.90      0.90      0.90        10
#    Mau-Ingin       0.82      0.90      0.86        20
#      Membaca       0.92      0.61      0.73        18
#         Nama       0.45      0.53      0.49        17
#    Sama-sama       0.84      0.89      0.86        18
#         Saya       0.88      0.91      0.89        23
#        Siapa       0.93      1.00      0.96        26
#      Sombong       1.00      1.00      1.00        22
#        Takut       0.89      0.84      0.86        19
#       Terima       0.73      0.86      0.79        22
#
#     accuracy                           0.88       346
#    macro avg       0.90      0.88      0.89       346
# weighted avg       0.89      0.88      0.89       346
#
# Confusion Matrix:

# %%
model_name = "pointnetv3"
device = "cpu"
train = []

id2label = {}

for index, folder in enumerate(os.listdir(DATA_PATH)):
    folder_path = os.path.join(DATA_PATH, folder)
    id2label[index] = folder
    for data_name in os.listdir(folder_path):
        data = np.load(os.path.join(folder_path, data_name), allow_pickle=True)
        # data = data[:-1]
        train.append({'label':index, 'data':data.tolist()})

random.shuffle(train)
TEST_SIZE = (int)(len(train) * 0.1)
VAL_SIZE = (int)(len(train) * 0.1)
test = train[-TEST_SIZE:]
val = train[-(TEST_SIZE + VAL_SIZE):-TEST_SIZE]
train = train[:-(TEST_SIZE + VAL_SIZE)]

train_tensors = []
for i in train:
    train_tensors.append({
        "data": torch.tensor(i["data"]).float(),
        "label": torch.tensor(i["label"]).long()
    })

test_tensors = []
for i in test:
    test_tensors.append({
        "data": torch.tensor(i["data"]).float(),
        "label": torch.tensor(i["label"]).long()
    })

val_tensors = []
for i in val:
    val_tensors.append({
        "data": torch.tensor(i["data"]).float(),
        "label": torch.tensor(i["label"]).long()
    })

train_loader = DataLoader(train_tensors, batch_size=32, shuffle=True)
test_loader = DataLoader(test_tensors, batch_size=32, shuffle=True)
val_loader = DataLoader(val_tensors, batch_size=32, shuffle=True)

# %%
num_classes = len(id2label)
pointnet = PointNet(classes=num_classes, device=device)

# %%
checkpoint_path = f"Checkpoint/{model_name}.pth"

def pointnetloss(outputs, labels, m3x3, m64x64, alpha = 0.0001):
    criterion = torch.nn.NLLLoss()
    bs=outputs.size(0)
    id3x3 = torch.eye(3, requires_grad=True).repeat(bs,1,1).to(device)
    id64x64 = torch.eye(64, requires_grad=True).repeat(bs,1,1).to(device)
    diff3x3 = id3x3 - torch.bmm(m3x3,m3x3.transpose(1,2))
    diff64x64 = id64x64 - torch.bmm(m64x64,m64x64.transpose(1,2))
    return criterion(outputs, labels) + alpha * (torch.norm(diff3x3)+torch.norm(diff64x64)) / float(bs)

def train(model, train_loader, val_loader, epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    for epoch in range(epochs): 
        model.train()
        running_loss = 0.0
        print_every_x = 16
        total_train = 0
        correct_train = 0
        for i, data in enumerate(train_loader, 0):
            inputs = data['data'].to(device)
            labels = data['label'].to(device)
            optimizer.zero_grad()
            outputs, m3x3, m64x64 = model(inputs.transpose(1,2))
            _, predicted = torch.max(outputs.data, 1)

            loss = pointnetloss(outputs, labels, m3x3, m64x64)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % print_every_x == print_every_x - 1:
                print(f"[Epoch: {epoch + 1}, Batch: {i + 1}, Loss: {running_loss / print_every_x:.4f}]")
                running_loss = 0.0
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        avg_train_loss = running_loss / len(train_loader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        model.eval()
        # validation
        total = correct = 0
        val_loss = 0
        with torch.no_grad():
            for data in val_loader:
                inputs, labels = data['data'].to(device).float(), data['label'].to(device)
                outputs, m3x3, m64x64 = model(inputs.transpose(1,2))
                loss = pointnetloss(outputs, labels, m3x3, m64x64)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * correct / total
        val_losses.append(avg_val_loss)
        val_accuracies.append(val_accuracy)
        print(f'Epoch {epoch + 1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Train Accuracy: {train_accuracy:.2f}% | Val Loss: {avg_val_loss:.4f} | Val Accuracy: {val_accuracy:.2f}%')
    return train_losses, val_losses, train_accuracies, val_accuracies
optimizer = torch.optim.Adam(pointnet.parameters(), lr=0.00025)
train_loss, val_loss, train_acc, val_acc = train(pointnet, train_loader, val_loader, epochs=80)
torch.save(pointnet.state_dict(), checkpoint_path)
# Out:
# [Epoch: 1, Batch: 16, Loss: 2.8913]
# [Epoch: 1, Batch: 32, Loss: 2.8051]
# [Epoch: 1, Batch: 48, Loss: 2.6860]
# [Epoch: 1, Batch: 64, Loss: 2.5992]
# [Epoch: 1, Batch: 80, Loss: 2.5634]
# Epoch 1/80 | Train Loss: 0.1971 | Train Accuracy: 16.13% | Val Loss: 3.3798 | Val Accuracy: 5.49%
# [Epoch: 2, Batch: 16, Loss: 2.4070]
# [Epoch: 2, Batch: 32, Loss: 2.3633]
# [Epoch: 2, Batch: 48, Loss: 2.2821]
# [Epoch: 2, Batch: 64, Loss: 2.3062]
# [Epoch: 2, Batch: 80, Loss: 2.1542]
# Epoch 2/80 | Train Loss: 0.1646 | Train Accuracy: 28.82% | Val Loss: 3.8672 | Val Accuracy: 5.49%
# [Epoch: 3, Batch: 16, Loss: 2.1804]
# [Epoch: 3, Batch: 32, Loss: 2.0302]
# [Epoch: 3, Batch: 48, Loss: 2.0164]
# [Epoch: 3, Batch: 64, Loss: 2.1174]
# [Epoch: 3, Batch: 80, Loss: 2.0665]
# Epoch 3/80 | Train Loss: 0.1679 | Train Accuracy: 33.30% | Val Loss: 2.2775 | Val Accuracy: 28.32%
# [Epoch: 4, Batch: 16, Loss: 1.9109]
# [Epoch: 4, Batch: 32, Loss: 1.9140]
# [Epoch: 4, Batch: 48, Loss: 1.8830]
# [Epoch: 4, Batch: 64, Loss: 1.8491]
# [Epoch: 4, Batch: 80, Loss: 1.8923]
# Epoch 4/80 | Train Loss: 0.1383 | Train Accuracy: 39.83% | Val Loss: 4.2282 | Val Accuracy: 5.49%
# [Epoch: 5, Batch: 16, Loss: 1.8257]
# [Epoch: 5, Batch: 32, Loss: 1.7223]
# [Epoch: 5, Batch: 48, Loss: 1.7389]
# [Epoch: 5, Batch: 64, Loss: 1.6383]
# [Epoch: 5, Batch: 80, Loss: 1.8121]
# Epoch 5/80 | Train Loss: 0.1384 | Train Accuracy: 44.48% | Val Loss: 4.2582 | Val Accuracy: 5.49%
# [Epoch: 6, Batch: 16, Loss: 1.5863]
# [Epoch: 6, Batch: 32, Loss: 1.6886]
# [Epoch: 6, Batch: 48, Loss: 1.6054]
# [Epoch: 6, Batch: 64, Loss: 1.5517]
# [Epoch: 6, Batch: 80, Loss: 1.7516]
# Epoch 6/80 | Train Loss: 0.1259 | Train Accuracy: 48.95% | Val Loss: 4.5556 | Val Accuracy: 5.49%
# [Epoch: 7, Batch: 16, Loss: 1.5695]
# [Epoch: 7, Batch: 32, Loss: 1.6191]
# [Epoch: 7, Batch: 48, Loss: 1.4514]
# [Epoch: 7, Batch: 64, Loss: 1.4802]
# [Epoch: 7, Batch: 80, Loss: 1.4231]
# Epoch 7/80 | Train Loss: 0.1183 | Train Accuracy: 53.54% | Val Loss: 2.2422 | Val Accuracy: 32.95%
# [Epoch: 8, Batch: 16, Loss: 1.4136]
# [Epoch: 8, Batch: 32, Loss: 1.3661]
# [Epoch: 8, Batch: 48, Loss: 1.4017]
# [Epoch: 8, Batch: 64, Loss: 1.2535]
# [Epoch: 8, Batch: 80, Loss: 1.4716]
# Epoch 8/80 | Train Loss: 0.1078 | Train Accuracy: 57.11% | Val Loss: 3.5141 | Val Accuracy: 7.80%
# [Epoch: 9, Batch: 16, Loss: 1.2799]
# [Epoch: 9, Batch: 32, Loss: 1.2317]
# [Epoch: 9, Batch: 48, Loss: 1.3181]
# [Epoch: 9, Batch: 64, Loss: 1.4027]
# [Epoch: 9, Batch: 80, Loss: 1.3998]
# Epoch 9/80 | Train Loss: 0.1050 | Train Accuracy: 59.49% | Val Loss: 4.7067 | Val Accuracy: 4.05%
# [Epoch: 10, Batch: 16, Loss: 1.1599]
# [Epoch: 10, Batch: 32, Loss: 1.1915]
# [Epoch: 10, Batch: 48, Loss: 1.1595]
# [Epoch: 10, Batch: 64, Loss: 1.1371]
# [Epoch: 10, Batch: 80, Loss: 1.3473]
# Epoch 10/80 | Train Loss: 0.1006 | Train Accuracy: 62.70% | Val Loss: 4.6045 | Val Accuracy: 4.05%
# [Epoch: 11, Batch: 16, Loss: 1.1063]
# [Epoch: 11, Batch: 32, Loss: 1.1217]
# [Epoch: 11, Batch: 48, Loss: 1.1722]
# [Epoch: 11, Batch: 64, Loss: 1.1124]
# [Epoch: 11, Batch: 80, Loss: 1.3764]
# Epoch 11/80 | Train Loss: 0.1206 | Train Accuracy: 62.77% | Val Loss: 4.3279 | Val Accuracy: 4.05%
# [Epoch: 12, Batch: 16, Loss: 1.2682]
# [Epoch: 12, Batch: 32, Loss: 1.0919]
# [Epoch: 12, Batch: 48, Loss: 0.9822]
# [Epoch: 12, Batch: 64, Loss: 1.1503]
# [Epoch: 12, Batch: 80, Loss: 1.0846]
# Epoch 12/80 | Train Loss: 0.0879 | Train Accuracy: 66.63% | Val Loss: 3.7791 | Val Accuracy: 6.65%
# [Epoch: 13, Batch: 16, Loss: 1.1743]
# [Epoch: 13, Batch: 32, Loss: 1.0293]
# [Epoch: 13, Batch: 48, Loss: 1.0762]
# [Epoch: 13, Batch: 64, Loss: 1.0280]
# [Epoch: 13, Batch: 80, Loss: 1.0164]
# Epoch 13/80 | Train Loss: 0.0839 | Train Accuracy: 67.75% | Val Loss: 1.3274 | Val Accuracy: 58.09%
# [Epoch: 14, Batch: 16, Loss: 1.0766]
# [Epoch: 14, Batch: 32, Loss: 0.9525]
# [Epoch: 14, Batch: 48, Loss: 0.8670]
# [Epoch: 14, Batch: 64, Loss: 0.9690]
# [Epoch: 14, Batch: 80, Loss: 0.9528]
# Epoch 14/80 | Train Loss: 0.1083 | Train Accuracy: 69.70% | Val Loss: 4.8449 | Val Accuracy: 4.05%
# [Epoch: 15, Batch: 16, Loss: 0.9904]
# [Epoch: 15, Batch: 32, Loss: 1.1224]
# [Epoch: 15, Batch: 48, Loss: 1.0328]
# [Epoch: 15, Batch: 64, Loss: 0.9326]
# [Epoch: 15, Batch: 80, Loss: 0.8601]
# Epoch 15/80 | Train Loss: 0.0672 | Train Accuracy: 70.71% | Val Loss: 3.4825 | Val Accuracy: 11.27%
# [Epoch: 16, Batch: 16, Loss: 1.0167]
# [Epoch: 16, Batch: 32, Loss: 1.0281]
# [Epoch: 16, Batch: 48, Loss: 0.8932]
# [Epoch: 16, Batch: 64, Loss: 0.8250]
# [Epoch: 16, Batch: 80, Loss: 0.8973]
# Epoch 16/80 | Train Loss: 0.0687 | Train Accuracy: 72.01% | Val Loss: 1.6772 | Val Accuracy: 46.53%
# [Epoch: 17, Batch: 16, Loss: 0.8750]
# [Epoch: 17, Batch: 32, Loss: 0.8605]
# [Epoch: 17, Batch: 48, Loss: 0.7273]
# [Epoch: 17, Batch: 64, Loss: 0.8458]
# [Epoch: 17, Batch: 80, Loss: 1.0659]
# Epoch 17/80 | Train Loss: 0.0725 | Train Accuracy: 73.59% | Val Loss: 4.3366 | Val Accuracy: 4.34%
# [Epoch: 18, Batch: 16, Loss: 0.8786]
# [Epoch: 18, Batch: 32, Loss: 0.7391]
# [Epoch: 18, Batch: 48, Loss: 0.7607]
# [Epoch: 18, Batch: 64, Loss: 0.9838]
# [Epoch: 18, Batch: 80, Loss: 0.8315]
# Epoch 18/80 | Train Loss: 0.0775 | Train Accuracy: 74.89% | Val Loss: 3.9564 | Val Accuracy: 10.98%
# [Epoch: 19, Batch: 16, Loss: 0.7270]
# [Epoch: 19, Batch: 32, Loss: 0.8042]
# [Epoch: 19, Batch: 48, Loss: 0.9153]
# [Epoch: 19, Batch: 64, Loss: 0.8324]
# [Epoch: 19, Batch: 80, Loss: 0.8151]
# Epoch 19/80 | Train Loss: 0.0802 | Train Accuracy: 74.24% | Val Loss: 4.4231 | Val Accuracy: 4.05%
# [Epoch: 20, Batch: 16, Loss: 0.7503]
# [Epoch: 20, Batch: 32, Loss: 0.6512]
# [Epoch: 20, Batch: 48, Loss: 0.7601]
# [Epoch: 20, Batch: 64, Loss: 0.7907]
# [Epoch: 20, Batch: 80, Loss: 0.8278]
# Epoch 20/80 | Train Loss: 0.0845 | Train Accuracy: 76.70% | Val Loss: 4.4515 | Val Accuracy: 4.05%
# [Epoch: 21, Batch: 16, Loss: 0.6760]
# [Epoch: 21, Batch: 32, Loss: 0.6953]
# [Epoch: 21, Batch: 48, Loss: 0.6263]
# [Epoch: 21, Batch: 64, Loss: 0.8537]
# [Epoch: 21, Batch: 80, Loss: 0.7424]
# Epoch 21/80 | Train Loss: 0.0798 | Train Accuracy: 77.60% | Val Loss: 4.3997 | Val Accuracy: 4.05%
# [Epoch: 22, Batch: 16, Loss: 0.6208]
# [Epoch: 22, Batch: 32, Loss: 0.7766]
# [Epoch: 22, Batch: 48, Loss: 0.6632]
# [Epoch: 22, Batch: 64, Loss: 0.6811]
# [Epoch: 22, Batch: 80, Loss: 0.8732]
# Epoch 22/80 | Train Loss: 0.0690 | Train Accuracy: 77.71% | Val Loss: 4.7080 | Val Accuracy: 4.34%
# [Epoch: 23, Batch: 16, Loss: 0.6556]
# [Epoch: 23, Batch: 32, Loss: 0.6380]
# [Epoch: 23, Batch: 48, Loss: 0.8919]
# [Epoch: 23, Batch: 64, Loss: 0.5901]
# [Epoch: 23, Batch: 80, Loss: 0.6955]
# Epoch 23/80 | Train Loss: 0.0680 | Train Accuracy: 78.86% | Val Loss: 4.1812 | Val Accuracy: 14.16%
# [Epoch: 24, Batch: 16, Loss: 0.6343]
# [Epoch: 24, Batch: 32, Loss: 0.5578]
# [Epoch: 24, Batch: 48, Loss: 0.7307]
# [Epoch: 24, Batch: 64, Loss: 0.8322]
# [Epoch: 24, Batch: 80, Loss: 0.6758]
# Epoch 24/80 | Train Loss: 0.0587 | Train Accuracy: 78.72% | Val Loss: 4.4186 | Val Accuracy: 11.56%
# [Epoch: 25, Batch: 16, Loss: 0.5767]
# [Epoch: 25, Batch: 32, Loss: 0.7809]
# [Epoch: 25, Batch: 48, Loss: 0.8027]
# [Epoch: 25, Batch: 64, Loss: 0.5795]
# [Epoch: 25, Batch: 80, Loss: 0.5644]
# Epoch 25/80 | Train Loss: 0.0380 | Train Accuracy: 80.48% | Val Loss: 3.9185 | Val Accuracy: 16.18%
# [Epoch: 26, Batch: 16, Loss: 0.5074]
# [Epoch: 26, Batch: 32, Loss: 0.7364]
# [Epoch: 26, Batch: 48, Loss: 0.5869]
# [Epoch: 26, Batch: 64, Loss: 0.5794]
# [Epoch: 26, Batch: 80, Loss: 0.8331]
# Epoch 26/80 | Train Loss: 0.0421 | Train Accuracy: 80.63% | Val Loss: 5.1183 | Val Accuracy: 4.05%
# [Epoch: 27, Batch: 16, Loss: 0.5299]
# [Epoch: 27, Batch: 32, Loss: 0.7044]
# [Epoch: 27, Batch: 48, Loss: 0.5120]
# [Epoch: 27, Batch: 64, Loss: 0.5463]
# [Epoch: 27, Batch: 80, Loss: 0.6998]
# Epoch 27/80 | Train Loss: 0.0498 | Train Accuracy: 81.24% | Val Loss: 4.6378 | Val Accuracy: 8.67%
# [Epoch: 28, Batch: 16, Loss: 0.4792]
# [Epoch: 28, Batch: 32, Loss: 0.5096]
# [Epoch: 28, Batch: 48, Loss: 0.8067]
# [Epoch: 28, Batch: 64, Loss: 0.5405]
# [Epoch: 28, Batch: 80, Loss: 0.4815]
# Epoch 28/80 | Train Loss: 0.0401 | Train Accuracy: 83.04% | Val Loss: 4.0246 | Val Accuracy: 17.63%
# [Epoch: 29, Batch: 16, Loss: 0.6713]
# [Epoch: 29, Batch: 32, Loss: 0.5089]
# [Epoch: 29, Batch: 48, Loss: 0.6484]
# [Epoch: 29, Batch: 64, Loss: 0.5744]
# [Epoch: 29, Batch: 80, Loss: 0.5030]
# Epoch 29/80 | Train Loss: 0.0405 | Train Accuracy: 82.32% | Val Loss: 3.2420 | Val Accuracy: 24.28%
# [Epoch: 30, Batch: 16, Loss: 0.4294]
# [Epoch: 30, Batch: 32, Loss: 0.6852]
# [Epoch: 30, Batch: 48, Loss: 0.5105]
# [Epoch: 30, Batch: 64, Loss: 0.6227]
# [Epoch: 30, Batch: 80, Loss: 0.5196]
# Epoch 30/80 | Train Loss: 0.0464 | Train Accuracy: 82.90% | Val Loss: 4.5199 | Val Accuracy: 13.29%
# [Epoch: 31, Batch: 16, Loss: 0.4482]
# [Epoch: 31, Batch: 32, Loss: 0.5917]
# [Epoch: 31, Batch: 48, Loss: 0.5670]
# [Epoch: 31, Batch: 64, Loss: 0.4625]
# [Epoch: 31, Batch: 80, Loss: 0.5179]
# Epoch 31/80 | Train Loss: 0.0431 | Train Accuracy: 83.87% | Val Loss: 3.7135 | Val Accuracy: 15.90%
# [Epoch: 32, Batch: 16, Loss: 0.4017]
# [Epoch: 32, Batch: 32, Loss: 0.5333]
# [Epoch: 32, Batch: 48, Loss: 0.5709]
# [Epoch: 32, Batch: 64, Loss: 0.6001]
# [Epoch: 32, Batch: 80, Loss: 0.5314]
# Epoch 32/80 | Train Loss: 0.0381 | Train Accuracy: 83.77% | Val Loss: 4.9587 | Val Accuracy: 7.23%
# [Epoch: 33, Batch: 16, Loss: 0.4274]
# [Epoch: 33, Batch: 32, Loss: 0.3398]
# [Epoch: 33, Batch: 48, Loss: 0.8146]
# [Epoch: 33, Batch: 64, Loss: 0.4487]
# [Epoch: 33, Batch: 80, Loss: 0.5648]
# Epoch 33/80 | Train Loss: 0.0439 | Train Accuracy: 84.09% | Val Loss: 3.7718 | Val Accuracy: 17.92%
# [Epoch: 34, Batch: 16, Loss: 0.3939]
# [Epoch: 34, Batch: 32, Loss: 0.8025]
# [Epoch: 34, Batch: 48, Loss: 0.5141]
# [Epoch: 34, Batch: 64, Loss: 0.4148]
# [Epoch: 34, Batch: 80, Loss: 0.3981]
# Epoch 34/80 | Train Loss: 0.0284 | Train Accuracy: 84.56% | Val Loss: 2.6657 | Val Accuracy: 31.79%
# [Epoch: 35, Batch: 16, Loss: 0.3767]
# [Epoch: 35, Batch: 32, Loss: 0.4340]
# [Epoch: 35, Batch: 48, Loss: 0.5506]
# [Epoch: 35, Batch: 64, Loss: 0.5972]
# [Epoch: 35, Batch: 80, Loss: 0.4956]
# Epoch 35/80 | Train Loss: 0.0292 | Train Accuracy: 85.89% | Val Loss: 4.6425 | Val Accuracy: 12.72%
# [Epoch: 36, Batch: 16, Loss: 0.3112]
# [Epoch: 36, Batch: 32, Loss: 0.4508]
# [Epoch: 36, Batch: 48, Loss: 0.3639]
# [Epoch: 36, Batch: 64, Loss: 0.5392]
# [Epoch: 36, Batch: 80, Loss: 0.4727]
# Epoch 36/80 | Train Loss: 0.0543 | Train Accuracy: 86.22% | Val Loss: 5.1079 | Val Accuracy: 4.05%
# [Epoch: 37, Batch: 16, Loss: 0.3889]
# [Epoch: 37, Batch: 32, Loss: 0.4316]
# [Epoch: 37, Batch: 48, Loss: 0.4783]
# [Epoch: 37, Batch: 64, Loss: 0.5846]
# [Epoch: 37, Batch: 80, Loss: 0.4070]
# Epoch 37/80 | Train Loss: 0.0314 | Train Accuracy: 86.22% | Val Loss: 4.9543 | Val Accuracy: 15.32%
# [Epoch: 38, Batch: 16, Loss: 0.4002]
# [Epoch: 38, Batch: 32, Loss: 0.4908]
# [Epoch: 38, Batch: 48, Loss: 0.3364]
# [Epoch: 38, Batch: 64, Loss: 0.5186]
# [Epoch: 38, Batch: 80, Loss: 0.4692]
# Epoch 38/80 | Train Loss: 0.0350 | Train Accuracy: 86.11% | Val Loss: 5.2340 | Val Accuracy: 13.58%
# [Epoch: 39, Batch: 16, Loss: 0.4320]
# [Epoch: 39, Batch: 32, Loss: 0.4490]
# [Epoch: 39, Batch: 48, Loss: 0.5316]
# [Epoch: 39, Batch: 64, Loss: 0.5476]
# [Epoch: 39, Batch: 80, Loss: 0.3639]
# Epoch 39/80 | Train Loss: 0.0374 | Train Accuracy: 84.63% | Val Loss: 5.5041 | Val Accuracy: 8.67%
# [Epoch: 40, Batch: 16, Loss: 0.4445]
# [Epoch: 40, Batch: 32, Loss: 0.3082]
# [Epoch: 40, Batch: 48, Loss: 0.4764]
# [Epoch: 40, Batch: 64, Loss: 0.5714]
# [Epoch: 40, Batch: 80, Loss: 0.3310]
# Epoch 40/80 | Train Loss: 0.0279 | Train Accuracy: 87.41% | Val Loss: 5.1038 | Val Accuracy: 13.29%
# [Epoch: 41, Batch: 16, Loss: 0.4508]
# [Epoch: 41, Batch: 32, Loss: 0.3321]
# [Epoch: 41, Batch: 48, Loss: 0.3867]
# [Epoch: 41, Batch: 64, Loss: 0.3382]
# [Epoch: 41, Batch: 80, Loss: 0.5576]
# Epoch 41/80 | Train Loss: 0.0308 | Train Accuracy: 87.95% | Val Loss: 5.2219 | Val Accuracy: 8.09%
# [Epoch: 42, Batch: 16, Loss: 0.4111]
# [Epoch: 42, Batch: 32, Loss: 0.4698]
# [Epoch: 42, Batch: 48, Loss: 0.3704]
# [Epoch: 42, Batch: 64, Loss: 0.3311]
# [Epoch: 42, Batch: 80, Loss: 0.4253]
# Epoch 42/80 | Train Loss: 0.0655 | Train Accuracy: 86.54% | Val Loss: 5.3708 | Val Accuracy: 4.05%
# [Epoch: 43, Batch: 16, Loss: 0.2994]
# [Epoch: 43, Batch: 32, Loss: 0.4575]
# [Epoch: 43, Batch: 48, Loss: 0.2958]
# [Epoch: 43, Batch: 64, Loss: 0.5004]
# [Epoch: 43, Batch: 80, Loss: 0.3510]
# Epoch 43/80 | Train Loss: 0.0266 | Train Accuracy: 88.02% | Val Loss: 5.0564 | Val Accuracy: 14.45%
# [Epoch: 44, Batch: 16, Loss: 0.3306]
# [Epoch: 44, Batch: 32, Loss: 0.4593]
# [Epoch: 44, Batch: 48, Loss: 0.5112]
# [Epoch: 44, Batch: 64, Loss: 0.3620]
# [Epoch: 44, Batch: 80, Loss: 0.3320]
# Epoch 44/80 | Train Loss: 0.0342 | Train Accuracy: 87.45% | Val Loss: 3.9036 | Val Accuracy: 20.81%
# [Epoch: 45, Batch: 16, Loss: 0.3334]
# [Epoch: 45, Batch: 32, Loss: 0.4636]
# [Epoch: 45, Batch: 48, Loss: 0.3264]
# [Epoch: 45, Batch: 64, Loss: 0.2958]
# [Epoch: 45, Batch: 80, Loss: 0.3469]
# Epoch 45/80 | Train Loss: 0.0660 | Train Accuracy: 88.74% | Val Loss: 5.6840 | Val Accuracy: 4.05%
# [Epoch: 46, Batch: 16, Loss: 0.2838]
# [Epoch: 46, Batch: 32, Loss: 0.5205]
# [Epoch: 46, Batch: 48, Loss: 0.4976]
# [Epoch: 46, Batch: 64, Loss: 0.4078]
# [Epoch: 46, Batch: 80, Loss: 0.3248]
# Epoch 46/80 | Train Loss: 0.0310 | Train Accuracy: 87.77% | Val Loss: 3.9532 | Val Accuracy: 19.36%
# [Epoch: 47, Batch: 16, Loss: 0.5212]
# [Epoch: 47, Batch: 32, Loss: 0.2993]
# [Epoch: 47, Batch: 48, Loss: 0.5150]
# [Epoch: 47, Batch: 64, Loss: 0.3328]
# [Epoch: 47, Batch: 80, Loss: 0.2821]
# Epoch 47/80 | Train Loss: 0.0231 | Train Accuracy: 88.60% | Val Loss: 3.1896 | Val Accuracy: 23.41%
# [Epoch: 48, Batch: 16, Loss: 0.3961]
# [Epoch: 48, Batch: 32, Loss: 0.2956]
# [Epoch: 48, Batch: 48, Loss: 0.3201]
# [Epoch: 48, Batch: 64, Loss: 0.3997]
# [Epoch: 48, Batch: 80, Loss: 0.5363]
# Epoch 48/80 | Train Loss: 0.0273 | Train Accuracy: 88.49% | Val Loss: 6.0461 | Val Accuracy: 6.36%
# [Epoch: 49, Batch: 16, Loss: 0.3163]
# [Epoch: 49, Batch: 32, Loss: 0.3378]
# [Epoch: 49, Batch: 48, Loss: 0.4413]
# [Epoch: 49, Batch: 64, Loss: 0.3004]
# [Epoch: 49, Batch: 80, Loss: 0.4533]
# Epoch 49/80 | Train Loss: 0.0247 | Train Accuracy: 88.06% | Val Loss: 5.9975 | Val Accuracy: 13.58%
# [Epoch: 50, Batch: 16, Loss: 0.2207]
# [Epoch: 50, Batch: 32, Loss: 0.4576]
# [Epoch: 50, Batch: 48, Loss: 0.4601]
# [Epoch: 50, Batch: 64, Loss: 0.3882]
# [Epoch: 50, Batch: 80, Loss: 0.3296]
# Epoch 50/80 | Train Loss: 0.0278 | Train Accuracy: 88.96% | Val Loss: 3.7380 | Val Accuracy: 27.46%
# [Epoch: 51, Batch: 16, Loss: 0.2861]
# [Epoch: 51, Batch: 32, Loss: 0.2455]
# [Epoch: 51, Batch: 48, Loss: 0.4068]
# [Epoch: 51, Batch: 64, Loss: 0.2464]
# [Epoch: 51, Batch: 80, Loss: 0.3261]
# Epoch 51/80 | Train Loss: 0.0500 | Train Accuracy: 90.91% | Val Loss: 4.1031 | Val Accuracy: 3.47%
# [Epoch: 52, Batch: 16, Loss: 0.6032]
# [Epoch: 52, Batch: 32, Loss: 0.3250]
# [Epoch: 52, Batch: 48, Loss: 0.3062]
# [Epoch: 52, Batch: 64, Loss: 0.2774]
# [Epoch: 52, Batch: 80, Loss: 0.3117]
# Epoch 52/80 | Train Loss: 0.0208 | Train Accuracy: 89.32% | Val Loss: 1.4365 | Val Accuracy: 60.40%
# [Epoch: 53, Batch: 16, Loss: 0.2729]
# [Epoch: 53, Batch: 32, Loss: 0.2423]
# [Epoch: 53, Batch: 48, Loss: 0.4419]
# [Epoch: 53, Batch: 64, Loss: 0.4764]
# [Epoch: 53, Batch: 80, Loss: 0.3030]
# Epoch 53/80 | Train Loss: 0.0317 | Train Accuracy: 89.07% | Val Loss: 5.9802 | Val Accuracy: 12.72%
# [Epoch: 54, Batch: 16, Loss: 0.2198]
# [Epoch: 54, Batch: 32, Loss: 0.4438]
# [Epoch: 54, Batch: 48, Loss: 0.2661]
# [Epoch: 54, Batch: 64, Loss: 0.4912]
# [Epoch: 54, Batch: 80, Loss: 0.3494]
# Epoch 54/80 | Train Loss: 0.0195 | Train Accuracy: 90.12% | Val Loss: 5.8467 | Val Accuracy: 12.43%
# [Epoch: 55, Batch: 16, Loss: 0.2956]
# [Epoch: 55, Batch: 32, Loss: 0.2570]
# [Epoch: 55, Batch: 48, Loss: 0.4386]
# [Epoch: 55, Batch: 64, Loss: 0.4369]
# [Epoch: 55, Batch: 80, Loss: 0.2951]
# Epoch 55/80 | Train Loss: 0.0244 | Train Accuracy: 89.36% | Val Loss: 4.8678 | Val Accuracy: 17.63%
# [Epoch: 56, Batch: 16, Loss: 0.2294]
# [Epoch: 56, Batch: 32, Loss: 0.2293]
# [Epoch: 56, Batch: 48, Loss: 0.2583]
# [Epoch: 56, Batch: 64, Loss: 0.5651]
# [Epoch: 56, Batch: 80, Loss: 0.2631]
# Epoch 56/80 | Train Loss: 0.0237 | Train Accuracy: 90.69% | Val Loss: 5.5565 | Val Accuracy: 11.56%
# [Epoch: 57, Batch: 16, Loss: 0.4210]
# [Epoch: 57, Batch: 32, Loss: 0.3035]
# [Epoch: 57, Batch: 48, Loss: 0.4253]
# [Epoch: 57, Batch: 64, Loss: 0.3095]
# [Epoch: 57, Batch: 80, Loss: 0.3484]
# Epoch 57/80 | Train Loss: 0.0333 | Train Accuracy: 89.00% | Val Loss: 3.8477 | Val Accuracy: 21.97%
# [Epoch: 58, Batch: 16, Loss: 0.4306]
# [Epoch: 58, Batch: 32, Loss: 0.3063]
# [Epoch: 58, Batch: 48, Loss: 0.3833]
# [Epoch: 58, Batch: 64, Loss: 0.2454]
# [Epoch: 58, Batch: 80, Loss: 0.3154]
# Epoch 58/80 | Train Loss: 0.0259 | Train Accuracy: 89.54% | Val Loss: 5.1980 | Val Accuracy: 13.29%
# [Epoch: 59, Batch: 16, Loss: 0.4735]
# [Epoch: 59, Batch: 32, Loss: 0.2719]
# [Epoch: 59, Batch: 48, Loss: 0.2233]
# [Epoch: 59, Batch: 64, Loss: 0.1984]
# [Epoch: 59, Batch: 80, Loss: 0.4058]
# Epoch 59/80 | Train Loss: 0.0185 | Train Accuracy: 90.66% | Val Loss: 5.6610 | Val Accuracy: 8.38%
# [Epoch: 60, Batch: 16, Loss: 0.1639]
# [Epoch: 60, Batch: 32, Loss: 0.2384]
# [Epoch: 60, Batch: 48, Loss: 0.2245]
# [Epoch: 60, Batch: 64, Loss: 0.5926]
# [Epoch: 60, Batch: 80, Loss: 0.2388]
# Epoch 60/80 | Train Loss: 0.0202 | Train Accuracy: 90.76% | Val Loss: 6.1196 | Val Accuracy: 6.65%
# [Epoch: 61, Batch: 16, Loss: 0.1878]
# [Epoch: 61, Batch: 32, Loss: 0.1914]
# [Epoch: 61, Batch: 48, Loss: 0.3590]
# [Epoch: 61, Batch: 64, Loss: 0.2851]
# [Epoch: 61, Batch: 80, Loss: 0.4149]
# Epoch 61/80 | Train Loss: 0.0181 | Train Accuracy: 91.81% | Val Loss: 6.1219 | Val Accuracy: 8.96%
# [Epoch: 62, Batch: 16, Loss: 0.1525]
# [Epoch: 62, Batch: 32, Loss: 0.3412]
# [Epoch: 62, Batch: 48, Loss: 0.1693]
# [Epoch: 62, Batch: 64, Loss: 0.4391]
# [Epoch: 62, Batch: 80, Loss: 0.2048]
# Epoch 62/80 | Train Loss: 0.0270 | Train Accuracy: 92.53% | Val Loss: 4.9268 | Val Accuracy: 17.92%
# [Epoch: 63, Batch: 16, Loss: 0.2056]
# [Epoch: 63, Batch: 32, Loss: 0.3066]
# [Epoch: 63, Batch: 48, Loss: 0.2372]
# [Epoch: 63, Batch: 64, Loss: 0.3289]
# [Epoch: 63, Batch: 80, Loss: 0.4198]
# Epoch 63/80 | Train Loss: 0.0506 | Train Accuracy: 89.72% | Val Loss: 4.5839 | Val Accuracy: 5.20%
# [Epoch: 64, Batch: 16, Loss: 0.4062]
# [Epoch: 64, Batch: 32, Loss: 0.1669]
# [Epoch: 64, Batch: 48, Loss: 0.2670]
# [Epoch: 64, Batch: 64, Loss: 0.4144]
# [Epoch: 64, Batch: 80, Loss: 0.1873]
# Epoch 64/80 | Train Loss: 0.0113 | Train Accuracy: 91.59% | Val Loss: 5.0988 | Val Accuracy: 8.09%
# [Epoch: 65, Batch: 16, Loss: 0.3605]
# [Epoch: 65, Batch: 32, Loss: 0.1934]
# [Epoch: 65, Batch: 48, Loss: 0.3388]
# [Epoch: 65, Batch: 64, Loss: 0.1892]
# [Epoch: 65, Batch: 80, Loss: 0.2299]
# Epoch 65/80 | Train Loss: 0.0191 | Train Accuracy: 92.03% | Val Loss: 2.8339 | Val Accuracy: 29.77%
# [Epoch: 66, Batch: 16, Loss: 0.3780]
# [Epoch: 66, Batch: 32, Loss: 0.3851]
# [Epoch: 66, Batch: 48, Loss: 0.2153]
# [Epoch: 66, Batch: 64, Loss: 0.2060]
# [Epoch: 66, Batch: 80, Loss: 0.2408]
# Epoch 66/80 | Train Loss: 0.0160 | Train Accuracy: 91.63% | Val Loss: 1.7724 | Val Accuracy: 54.05%
# [Epoch: 67, Batch: 16, Loss: 0.1732]
# [Epoch: 67, Batch: 32, Loss: 0.1741]
# [Epoch: 67, Batch: 48, Loss: 0.2145]
# [Epoch: 67, Batch: 64, Loss: 0.4154]
# [Epoch: 67, Batch: 80, Loss: 0.3643]
# Epoch 67/80 | Train Loss: 0.0125 | Train Accuracy: 92.39% | Val Loss: 5.6617 | Val Accuracy: 7.51%
# [Epoch: 68, Batch: 16, Loss: 0.3094]
# [Epoch: 68, Batch: 32, Loss: 0.2376]
# [Epoch: 68, Batch: 48, Loss: 0.2759]
# [Epoch: 68, Batch: 64, Loss: 0.1989]
# [Epoch: 68, Batch: 80, Loss: 0.5507]
# Epoch 68/80 | Train Loss: 0.0218 | Train Accuracy: 90.69% | Val Loss: 6.5133 | Val Accuracy: 4.05%
# [Epoch: 69, Batch: 16, Loss: 0.2433]
# [Epoch: 69, Batch: 32, Loss: 0.2311]
# [Epoch: 69, Batch: 48, Loss: 0.4123]
# [Epoch: 69, Batch: 64, Loss: 0.3461]
# [Epoch: 69, Batch: 80, Loss: 0.2758]
# Epoch 69/80 | Train Loss: 0.0171 | Train Accuracy: 91.16% | Val Loss: 5.3140 | Val Accuracy: 10.98%
# [Epoch: 70, Batch: 16, Loss: 0.1699]
# [Epoch: 70, Batch: 32, Loss: 0.1622]
# [Epoch: 70, Batch: 48, Loss: 0.5624]
# [Epoch: 70, Batch: 64, Loss: 0.2437]
# [Epoch: 70, Batch: 80, Loss: 0.2051]
# Epoch 70/80 | Train Loss: 0.0151 | Train Accuracy: 92.21% | Val Loss: 5.0684 | Val Accuracy: 14.74%
# [Epoch: 71, Batch: 16, Loss: 0.3254]
# [Epoch: 71, Batch: 32, Loss: 0.2183]
# [Epoch: 71, Batch: 48, Loss: 0.1686]
# [Epoch: 71, Batch: 64, Loss: 0.2033]
# [Epoch: 71, Batch: 80, Loss: 0.3650]
# Epoch 71/80 | Train Loss: 0.0230 | Train Accuracy: 92.10% | Val Loss: 6.6119 | Val Accuracy: 4.05%
# [Epoch: 72, Batch: 16, Loss: 0.3776]
# [Epoch: 72, Batch: 32, Loss: 0.4180]
# [Epoch: 72, Batch: 48, Loss: 0.2100]
# [Epoch: 72, Batch: 64, Loss: 0.1726]
# [Epoch: 72, Batch: 80, Loss: 0.2272]
# Epoch 72/80 | Train Loss: 0.0173 | Train Accuracy: 92.03% | Val Loss: 2.9397 | Val Accuracy: 32.37%
# [Epoch: 73, Batch: 16, Loss: 0.3588]
# [Epoch: 73, Batch: 32, Loss: 0.3767]
# [Epoch: 73, Batch: 48, Loss: 0.2040]
# [Epoch: 73, Batch: 64, Loss: 0.2177]
# [Epoch: 73, Batch: 80, Loss: 0.1984]
# Epoch 73/80 | Train Loss: 0.0207 | Train Accuracy: 91.85% | Val Loss: 2.1220 | Val Accuracy: 44.80%
# [Epoch: 74, Batch: 16, Loss: 0.1833]
# [Epoch: 74, Batch: 32, Loss: 0.3726]
# [Epoch: 74, Batch: 48, Loss: 0.1669]
# [Epoch: 74, Batch: 64, Loss: 0.1971]
# [Epoch: 74, Batch: 80, Loss: 0.3673]
# Epoch 74/80 | Train Loss: 0.0152 | Train Accuracy: 92.53% | Val Loss: 5.2554 | Val Accuracy: 7.80%
# [Epoch: 75, Batch: 16, Loss: 0.1451]
# [Epoch: 75, Batch: 32, Loss: 0.3250]
# [Epoch: 75, Batch: 48, Loss: 0.3208]
# [Epoch: 75, Batch: 64, Loss: 0.2117]
# [Epoch: 75, Batch: 80, Loss: 0.1705]
# Epoch 75/80 | Train Loss: 0.0200 | Train Accuracy: 93.36% | Val Loss: 4.4966 | Val Accuracy: 20.23%
# [Epoch: 76, Batch: 16, Loss: 0.3312]
# [Epoch: 76, Batch: 32, Loss: 0.1440]
# [Epoch: 76, Batch: 48, Loss: 0.3324]
# [Epoch: 76, Batch: 64, Loss: 0.1408]
# [Epoch: 76, Batch: 80, Loss: 0.1641]
# Epoch 76/80 | Train Loss: 0.0154 | Train Accuracy: 93.40% | Val Loss: 4.3120 | Val Accuracy: 23.41%
# [Epoch: 77, Batch: 16, Loss: 0.1509]
# [Epoch: 77, Batch: 32, Loss: 0.1503]
# [Epoch: 77, Batch: 48, Loss: 0.3243]
# [Epoch: 77, Batch: 64, Loss: 0.1646]
# [Epoch: 77, Batch: 80, Loss: 0.3673]
# Epoch 77/80 | Train Loss: 0.0103 | Train Accuracy: 93.36% | Val Loss: 6.2562 | Val Accuracy: 4.05%
# [Epoch: 78, Batch: 16, Loss: 0.1474]
# [Epoch: 78, Batch: 32, Loss: 0.1526]
# [Epoch: 78, Batch: 48, Loss: 0.1720]
# [Epoch: 78, Batch: 64, Loss: 0.3934]
# [Epoch: 78, Batch: 80, Loss: 0.3981]
# Epoch 78/80 | Train Loss: 0.0116 | Train Accuracy: 92.82% | Val Loss: 6.0940 | Val Accuracy: 4.91%
# [Epoch: 79, Batch: 16, Loss: 0.3259]
# [Epoch: 79, Batch: 32, Loss: 0.1442]
# [Epoch: 79, Batch: 48, Loss: 0.4128]
# [Epoch: 79, Batch: 64, Loss: 0.2011]
# [Epoch: 79, Batch: 80, Loss: 0.2206]
# Epoch 79/80 | Train Loss: 0.0203 | Train Accuracy: 92.57% | Val Loss: 4.5217 | Val Accuracy: 15.61%
# [Epoch: 80, Batch: 16, Loss: 0.2578]
# [Epoch: 80, Batch: 32, Loss: 0.1899]
# [Epoch: 80, Batch: 48, Loss: 0.3587]
# [Epoch: 80, Batch: 64, Loss: 0.2223]
# [Epoch: 80, Batch: 80, Loss: 0.2100]
# Epoch 80/80 | Train Loss: 0.0181 | Train Accuracy: 92.75% | Val Loss: 4.4237 | Val Accuracy: 19.36%

# %%
pointnet = PointNet(classes=num_classes, device="cpu")
pointnet.load_from_pth(checkpoint_path)
pointnet.eval()

all_preds = []
all_labels = []
with torch.no_grad():
    for i, data in enumerate(test_loader):
        inputs, labels = data['data'].float(), data['label'].long()
        outputs, _, _ = pointnet(inputs.transpose(1,2))
        _, preds = torch.max(outputs.data, 1)
        all_preds += preds.numpy().tolist()
        all_labels += labels.numpy().tolist()

print(f"Accuracy: {accuracy_score(all_labels, all_preds)}")
print(f"Precision Score: {precision_score(all_labels, all_preds, average='weighted')}")
print(f"Recall Score: {recall_score(all_labels, all_preds, average='weighted')}")
print(f"F1 Score: {f1_score(all_labels, all_preds, average='weighted')}")

print(f"Classification Report: {classification_report(all_labels, all_preds, target_names=id2label.values())}")

display = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(all_labels, all_preds), display_labels = id2label.values())
fig, ax = plt.subplots(figsize=(8,8))
print(f"Confusion Matrix:\n")
display.plot(ax=ax, xticks_rotation='vertical')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

plt.plot(train_acc)
plt.plot(val_acc)
plt.title('PointNet Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(train_loss)
plt.plot(val_loss)
plt.title('PointNet Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# c:\Users\leozh\Leo\Coding\SignLanguageAI\Computer Vision Sign Language\PointNet.py:102: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(path, map_location=self.device))
# Accuracy: 0.1936416184971098
# Precision Score: 0.15531564584798796
# Recall Score: 0.1936416184971098
# F1 Score: 0.14435577540530503
# Classification Report:               precision    recall  f1-score   support
#
#         Anda       0.17      0.05      0.08        20
#          Apa       0.00      0.00      0.00        18
#     Berhenti       0.00      0.00      0.00        16
#        Bodoh       0.54      0.33      0.41        21
#       Cantik       0.00      0.00      0.00        22
#         Halo       0.00      0.00      0.00        15
#    Hati-hati       0.00      0.00      0.00        14
#        Lelah       0.00      0.00      0.00        17
#         Maaf       0.07      0.09      0.08        11
#        Makan       0.07      0.79      0.14        19
#    Mau-Ingin       0.00      0.00      0.00        17
#      Membaca       0.00      0.00      0.00        10
#         Nama       0.00      0.00      0.00        16
#    Sama-sama       0.00      0.00      0.00        19
#         Saya       0.89      0.42      0.57        19
#        Siapa       0.00      0.00      0.00        24
#      Sombong       0.46      0.75      0.57        24
#        Takut       0.32      0.61      0.42        28
#       Terima       0.00      0.00      0.00        16
#
#     accuracy                           0.19       346
#    macro avg       0.13      0.16      0.12       346
# weighted avg       0.16      0.19      0.14       346
# C:\Users\leozh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\leozh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\leozh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\leozh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Confusion Matrix:
